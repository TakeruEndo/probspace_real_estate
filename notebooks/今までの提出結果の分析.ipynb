# %%
import json
import pandas as pd
import numpy as np
# データ可視化ライブラリ
import matplotlib.pyplot as plt
# %matplotlib inline  
import pandas_profiling as pdp
import seaborn as sns

# %%
train = pd.read_csv('../data/raw/train_data.csv')
#スコア620
cat2 = pd.read_csv('sub_cat_2.csv')
# スコア400
lgbm6 = pd.read_csv('sub_lgbm_6.csv')
# 未提出
cat3 = pd.read_csv('sub_cat_3.csv')
cat3_cv = pd.read_csv('sub_cat_3_cv.csv')

# %%
plt.figure(figsize=(20,5))
res = 1
plt.plot(range(0,cat2.shape[0],res), cat2.y[0::res])
# 並べて表示も可能
plt.plot(range(0,lgbm6.shape[0],res), lgbm6.y[0::res])

plt.title('Test Data Predictions',size=16)
plt.show()

# %%
plt.figure(figsize=(20,5))
res = 1
plt.plot(range(0,cat3.shape[0],res), cat3.y[0::res])
# 並べて表示も可能
# plt.plot(range(0,lgbm6.shape[0],res), lgbm6.y[0::res])

plt.title('Test Data Predictions',size=16)
plt.show()

# %%
cat2['y'].describe()
# Out:
# count    34844.000000
# mean       320.501960
# std        774.042005
# min          0.000000
# 25%        119.066059
# 50%        189.470899
# 75%        288.885150
# max      38364.941170
# Name: y, dtype: float64

# %%
lgbm6['y'].describe()
# Out:
# count    34844.000000
# mean       248.565731
# std        606.396426
# min          0.000000
# 25%         94.830000
# 50%        147.010000
# 75%        218.760000
# max      39720.330000
# Name: y, dtype: float64

# %%
cat3['y'].describe()
# Out:
# count    34844.000000
# mean        62.375446
# std        150.017113
# min          0.000000
# 25%         22.460000
# 50%         37.180000
# 75%         57.000000
# max       7741.320000
# Name: y, dtype: float64

# %%
cat3_cv['y'].describe()
# Out:
# count    34844.000000
# mean        79.111231
# std        189.493195
# min          0.000000
# 25%         28.720000
# 50%         47.660000
# 75%         72.032500
# max       8665.110000
# Name: y, dtype: float64

# %%
train['y'].describe()
# Out:
# count    356344.000000
# mean         65.434766
# std         315.011339
# min           0.000500
# 25%          21.000000
# 50%          35.000000
# 75%          53.000000
# max       61000.000000
# Name: y, dtype: float64
