# %%
import pandas as pd
import numpy as np
import json
# データ可視化ライブラリ
import matplotlib.pyplot as plt
# %matplotlib inline  
import seaborn as sns
import re
from tqdm import tqdm_notebook as tqdm

import lightgbm as lgb
print('lightgbm version:', lgb.__version__)

from sklearn.metrics import mean_squared_error, roc_auc_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
import sklearn
print('sklearn version:', sklearn.__version__)
from sklearn.model_selection import train_test_split
from catboost import CatBoostRegressor
from catboost import Pool

import warnings
warnings.filterwarnings('ignore')
# Out:
# lightgbm version: 2.3.0
# sklearn version: 0.22.1
# /Users/endotakeru/opt/anaconda3/lib/python3.7/site-packages/lightgbm/__init__.py:48: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
train = pd.read_csv('../data/raw/train2.csv')
test = pd.read_csv('../data/raw/test2.csv')

# %%
drop_columns = ['OpenFloor', 'Workshop', 'D', 'S', 'Studio', 'Maisonette', 'K', 'R']
train = train.drop(drop_columns, axis=1)
test = test.drop(drop_columns, axis=1)
# highのtrainに幅を持たせるのは多分正解
train_high = train.query('MunicipalityCode < 13150 and Area > 400')
train_low = train.query('(MunicipalityCode < 13150 and Area < 600) or MunicipalityCode > 13150')
train_high_y = train_high['y']
train_high = train_high.drop('y', axis=1)

train_low_y = train_low['y']
train_low = train_low.drop('y', axis=1)
test = test.reset_index()

# 800のほうがいいかもしれない
test_high = test.query('MunicipalityCode < 13150 and Area >= 800')
test_low = test.query('(MunicipalityCode < 13150 and Area < 800) or MunicipalityCode > 13150')

test_high_data = test_high.drop('index', axis=1)
test_low_data = test_low.drop('index', axis=1)

# %%
### lowの予測
scores = []
y_low_pred = np.zeros(test_low_data.shape[0])
kf = KFold(n_splits=4, shuffle=True, random_state=71)
for tr_idx, va_idx in kf.split(train_low):
    tr_x, va_x = train_low.iloc[tr_idx], train_low.iloc[va_idx]
    tr_y, va_y = train_low_y.iloc[tr_idx], train_low_y.iloc[va_idx]

    train_data = lgb.Dataset(tr_x, tr_y)
    valid_data = lgb.Dataset(va_x, va_y)
    params = {
        'objective': 'regression',
        'metric': 'mape',
        'learning_rate': 0.001,
        'max_depth': -1,
        'num_leaves': 255,
        'max_bin': 255,
        'colsample_bytree': 0.8,
        'subsample': 0.8,
        'nthread': -1,
        'bagging_freq': 1,
        'verbose': -1,
        'seed': 1
#         'seed': random.randint(1, 100),
    }
    model = lgb.train(params, train_data, valid_sets=[train_data, valid_data],
                      num_boost_round=5000, early_stopping_rounds=200,
                      verbose_eval=200)

    y_val_pred = model.predict(va_x)
    val_score = np.sqrt(mean_squared_error(va_y, y_val_pred))
    y_low_pred  += model.predict(test_low_data, num_iteration=model.best_iteration)
    scores.append(val_score)

print('RMSE:', np.mean(scores))
# Out:
# Training until validation scores don't improve for 200 rounds
# [200]	training's mape: 1.36973	valid_1's mape: 1.37146
# [400]	training's mape: 1.18717	valid_1's mape: 1.18822
# [600]	training's mape: 1.03816	valid_1's mape: 1.03882
# [800]	training's mape: 0.915294	valid_1's mape: 0.915963
# [1000]	training's mape: 0.812775	valid_1's mape: 0.813514
# [1200]	training's mape: 0.727594	valid_1's mape: 0.728375
# [1400]	training's mape: 0.657637	valid_1's mape: 0.658692
# [1600]	training's mape: 0.599839	valid_1's mape: 0.601204
# [1800]	training's mape: 0.552669	valid_1's mape: 0.554522
# [2000]	training's mape: 0.513079	valid_1's mape: 0.515318
# [2200]	training's mape: 0.480165	valid_1's mape: 0.482772
# [2000]	training's mape: 0.509395	valid_1's mape: 0.520673
# [2200]	training's mape: 0.476682	valid_1's mape: 0.489011
# [2400]	training's mape: 0.448996	valid_1's mape: 0.462372
# [2600]	training's mape: 0.426047	valid_1's mape: 0.44042
# [2800]	training's mape: 0.406546	valid_1's mape: 0.42172
# [3000]	training's mape: 0.39002	valid_1's mape: 0.406115
# [3200]	training's mape: 0.37594	valid_1's mape: 0.392845
# [3400]	training's mape: 0.363709	valid_1's mape: 0.38159
# [3600]	training's mape: 0.353201	valid_1's mape: 0.371991
# [3800]	training's mape: 0.343871	valid_1's mape: 0.363605
# [4000]	training's mape: 0.335814	valid_1's mape: 0.356271
# [4200]	training's mape: 0.328784	valid_1's mape: 0.349972
# [4400]	training's mape: 0.322568	valid_1's mape: 0.344452
# [4600]	training's mape: 0.317115	valid_1's mape: 0.339746
# [4800]	training's mape: 0.312068	valid_1's mape: 0.335399
# [5000]	training's mape: 0.307736	valid_1's mape: 0.331685
# Did not meet early stopping. Best iteration is:
# [5000]	training's mape: 0.307736	valid_1's mape: 0.331685
# Training until validation scores don't improve for 200 rounds
# [200]	training's mape: 1.35285	valid_1's mape: 1.36373
# [400]	training's mape: 1.17248	valid_1's mape: 1.18508
# [600]	training's mape: 1.02541	valid_1's mape: 1.03944
# [800]	training's mape: 0.904418	valid_1's mape: 0.919476
# [1000]	training's mape: 0.803309	valid_1's mape: 0.819432
# [1200]	training's mape: 0.719468	valid_1's mape: 0.736357
# [1400]	training's mape: 0.650659	valid_1's mape: 0.668263
# [1600]	training's mape: 0.593647	valid_1's mape: 0.611722
# [1800]	training's mape: 0.547033	valid_1's mape: 0.565507
# [2000]	training's mape: 0.507887	valid_1's mape: 0.526849
# [2200]	training's mape: 0.475503	valid_1's mape: 0.494934
# [2400]	training's mape: 0.448471	valid_1's mape: 0.468145
# [2600]	training's mape: 0.426004	valid_1's mape: 0.445992
# [2800]	training's mape: 0.406794	valid_1's mape: 0.427031
# [3000]	training's mape: 0.390584	valid_1's mape: 0.410931
# [3200]	training's mape: 0.376709	valid_1's mape: 0.397146
# [3400]	training's mape: 0.364664	valid_1's mape: 0.385395
# [3600]	training's mape: 0.354329	valid_1's mape: 0.375289
# [3800]	training's mape: 0.3453	valid_1's mape: 0.366595
# [4000]	training's mape: 0.337281	valid_1's mape: 0.35887
# [4200]	training's mape: 0.330363	valid_1's mape: 0.352468
# [4400]	training's mape: 0.324255	valid_1's mape: 0.346809
# [4600]	training's mape: 0.318945	valid_1's mape: 0.341876
# [4800]	training's mape: 0.314095	valid_1's mape: 0.337468
# [5000]	training's mape: 0.30974	valid_1's mape: 0.333571
# Did not meet early stopping. Best iteration is:
# [5000]	training's mape: 0.30974	valid_1's mape: 0.333571
# RMSE: 72.81747045107932

# %%
### highの予測
scores = []
y_high_pred = np.zeros(test_high_data.shape[0])
kf = KFold(n_splits=4, shuffle=True, random_state=71)
for tr_idx, va_idx in kf.split(train_high):
    tr_x, va_x = train_high.iloc[tr_idx], train_high.iloc[va_idx]
    tr_y, va_y = train_high_y.iloc[tr_idx], train_high_y.iloc[va_idx]

    train_data = lgb.Dataset(tr_x, tr_y)
    valid_data = lgb.Dataset(va_x, va_y)
    params = {
        'objective': 'regression',
        'metric': 'mape',
        'learning_rate': 0.001,
        'max_depth': -1,
        'num_leaves': 200,
        'max_bin': 255,
        'colsample_bytree': 0.8,
        'subsample': 0.8,
        'nthread': -1,
        'bagging_freq': 1,
        'verbose': -1,
        'seed': 1
#         'seed': random.randint(1, 100),
    }
    model = lgb.train(params, train_data, valid_sets=[train_data, valid_data],
                      num_boost_round=5000, early_stopping_rounds=100,
                      verbose_eval=200)

    y_val_pred = model.predict(va_x)
    val_score = np.sqrt(mean_squared_error(va_y, y_val_pred*1.03))
    y_high_pred  += model.predict(test_high_data, num_iteration=model.best_iteration)
    scores.append(val_score)

print('RMSE:', np.mean(scores))
# Out:
# Training until validation scores don't improve for 100 rounds
# [200]	training's mape: 2.16954	valid_1's mape: 2.16155
# [400]	training's mape: 1.84335	valid_1's mape: 1.84664
# [600]	training's mape: 1.57593	valid_1's mape: 1.59102
# [800]	training's mape: 1.35524	valid_1's mape: 1.38181
# [1000]	training's mape: 1.17287	valid_1's mape: 1.20972
# [1200]	training's mape: 1.02296	valid_1's mape: 1.06975
# [1400]	training's mape: 0.897566	valid_1's mape: 0.954012
# [1600]	training's mape: 0.79304	valid_1's mape: 0.859085
# [1800]	training's mape: 0.706254	valid_1's mape: 0.782441
# [2000]	training's mape: 0.633693	valid_1's mape: 0.719364
# [2200]	training's mape: 0.573692	valid_1's mape: 0.668593
# [2400]	training's mape: 0.52488	valid_1's mape: 0.629375
# [2600]	training's mape: 0.484368	valid_1's mape: 0.598592
# [2800]	training's mape: 0.450882	valid_1's mape: 0.575244
# [3000]	training's mape: 0.422996	valid_1's mape: 0.556623
# [3200]	training's mape: 0.399782	valid_1's mape: 0.543404
# [3400]	training's mape: 0.37999	valid_1's mape: 0.532961
# [3600]	training's mape: 0.36338	valid_1's mape: 0.524534
# [3800]	training's mape: 0.349635	valid_1's mape: 0.518463
# [4000]	training's mape: 0.33801	valid_1's mape: 0.513699
# [4200]	training's mape: 0.329145	valid_1's mape: 0.511665
# [4400]	training's mape: 0.320761	valid_1's mape: 0.510567
# [4600]	training's mape: 0.313416	valid_1's mape: 0.509255
# [4800]	training's mape: 0.307058	valid_1's mape: 0.509221
# Early stopping, best iteration is:
# [4709]	training's mape: 0.309819	valid_1's mape: 0.508916
# Training until validation scores don't improve for 100 rounds
# [200]	training's mape: 2.05815	valid_1's mape: 1.99255
# [400]	training's mape: 1.75203	valid_1's mape: 1.7121
# [600]	training's mape: 1.50036	valid_1's mape: 1.48277
# [800]	training's mape: 1.29304	valid_1's mape: 1.29623
# [1000]	training's mape: 1.12091	valid_1's mape: 1.14243
# [1200]	training's mape: 0.979448	valid_1's mape: 1.01677
# [1400]	training's mape: 0.860523	valid_1's mape: 0.912691
# [1600]	training's mape: 0.76144	valid_1's mape: 0.82711
# [1800]	training's mape: 0.679058	valid_1's mape: 0.757944
# [2000]	training's mape: 0.610127	valid_1's mape: 0.701405
# [2200]	training's mape: 0.553336	valid_1's mape: 0.655213
# [2400]	training's mape: 0.505934	valid_1's mape: 0.618212
# [2600]	training's mape: 0.466006	valid_1's mape: 0.588515
# [2800]	training's mape: 0.432469	valid_1's mape: 0.564826
# [3000]	training's mape: 0.404604	valid_1's mape: 0.545982
# [3200]	training's mape: 0.381765	valid_1's mape: 0.531207
# [4000]	training's mape: 0.34115	valid_1's mape: 0.606444
# [4200]	training's mape: 0.332162	valid_1's mape: 0.603871
# [4400]	training's mape: 0.323801	valid_1's mape: 0.602565
# [4600]	training's mape: 0.315978	valid_1's mape: 0.602019
# Early stopping, best iteration is:
# [4605]	training's mape: 0.315789	valid_1's mape: 0.601982
# RMSE: 1546.0220604508995

# %%
### highの予測
scores = []
y_high_pred = np.zeros(test_high_data.shape[0])
kf = KFold(n_splits=4, shuffle=True, random_state=71)
for tr_idx, va_idx in kf.split(train_high):
    tr_x, va_x = train_high.iloc[tr_idx], train_high.iloc[va_idx]
    tr_y, va_y = train_high_y.iloc[tr_idx], train_high_y.iloc[va_idx]

    train_data = lgb.Dataset(tr_x, tr_y)
    valid_data = lgb.Dataset(va_x, va_y)
    params = {
        'objective': 'regression',
        'metric': 'mape',
        'learning_rate': 0.001,
        'max_depth': -1,
        'num_leaves': 200,
        'max_bin': 255,
        'colsample_bytree': 0.8,
        'subsample': 0.8,
        'nthread': -1,
        'bagging_freq': 1,
        'verbose': -1,
        'seed': 1
#         'seed': random.randint(1, 100),
    }
    model = lgb.train(params, train_data, valid_sets=[train_data, valid_data],
                      num_boost_round=5000, early_stopping_rounds=100,
                      verbose_eval=200)

    y_val_pred = model.predict(va_x)
    val_score = np.sqrt(mean_squared_error(va_y, y_val_pred*1.03))
    y_high_pred  += model.predict(test_high_data, num_iteration=model.best_iteration)
    scores.append(val_score)

print('RMSE:', np.mean(scores))
# Out:
# Training until validation scores don't improve for 100 rounds
# [200]	training's mape: 2.16954	valid_1's mape: 2.16155
# [400]	training's mape: 1.84335	valid_1's mape: 1.84664
# [600]	training's mape: 1.57593	valid_1's mape: 1.59102
# [800]	training's mape: 1.35524	valid_1's mape: 1.38181
# [1000]	training's mape: 1.17287	valid_1's mape: 1.20972
# [1200]	training's mape: 1.02296	valid_1's mape: 1.06975
# [1400]	training's mape: 0.897566	valid_1's mape: 0.954012
# [1600]	training's mape: 0.79304	valid_1's mape: 0.859085
# [1800]	training's mape: 0.706254	valid_1's mape: 0.782441
# [2000]	training's mape: 0.633693	valid_1's mape: 0.719364
# [2200]	training's mape: 0.573692	valid_1's mape: 0.668593
# [2400]	training's mape: 0.52488	valid_1's mape: 0.629375
# [2600]	training's mape: 0.484368	valid_1's mape: 0.598592
# [2800]	training's mape: 0.450882	valid_1's mape: 0.575244
# [3000]	training's mape: 0.422996	valid_1's mape: 0.556623
# [3200]	training's mape: 0.399782	valid_1's mape: 0.543404
# [3400]	training's mape: 0.37999	valid_1's mape: 0.532961
# [3600]	training's mape: 0.36338	valid_1's mape: 0.524534
# [3800]	training's mape: 0.349635	valid_1's mape: 0.518463
# [4000]	training's mape: 0.33801	valid_1's mape: 0.513699
# [4200]	training's mape: 0.329145	valid_1's mape: 0.511665
# [4400]	training's mape: 0.320761	valid_1's mape: 0.510567
# [4600]	training's mape: 0.313416	valid_1's mape: 0.509255
# [4800]	training's mape: 0.307058	valid_1's mape: 0.509221
# Early stopping, best iteration is:
# [4709]	training's mape: 0.309819	valid_1's mape: 0.508916
# Training until validation scores don't improve for 100 rounds
# [200]	training's mape: 2
# [1000]	training's mape: 1.16635	valid_1's mape: 1.2327
# [1200]	training's mape: 1.01842	valid_1's mape: 1.10594
# [1400]	training's mape: 0.89363	valid_1's mape: 1.00012
# [1600]	training's mape: 0.789658	valid_1's mape: 0.913895
# [1800]	training's mape: 0.703492	valid_1's mape: 0.844017
# [2000]	training's mape: 0.631802	valid_1's mape: 0.787349
# [2200]	training's mape: 0.572356	valid_1's mape: 0.742154
# [2400]	training's mape: 0.523874	valid_1's mape: 0.707649
# [2600]	training's mape: 0.482947	valid_1's mape: 0.680094
# [2800]	training's mape: 0.449301	valid_1's mape: 0.658767
# [3000]	training's mape: 0.421561	valid_1's mape: 0.643368
# [3200]	training's mape: 0.399059	valid_1's mape: 0.631233
# [3400]	training's mape: 0.38061	valid_1's mape: 0.622495
# [3600]	training's mape: 0.365239	valid_1's mape: 0.615347
# [3800]	training's mape: 0.352329	valid_1's mape: 0.610541
# [4000]	training's mape: 0.34115	valid_1's mape: 0.606444
# [4200]	training's mape: 0.332162	valid_1's mape: 0.603871
# [4400]	training's mape: 0.323801	valid_1's mape: 0.602565
# [4600]	training's mape: 0.315978	valid_1's mape: 0.602019
# Early stopping, best iteration is:
# [4605]	training's mape: 0.315789	valid_1's mape: 0.601982
# RMSE: 1544.851377204057

# %%
test_high['pred'] = y_high_pred*1.03
test_low['pred'] = y_low_pred
test = pd.concat((test_high, test_low))
test = test.sort_values('index')
y_pred  = test['pred']
y_pred = np.round(y_pred, 2)

# %%
submit = pd.read_csv('../data/raw/test_data.csv')
sub = pd.DataFrame({'id': submit['id'], 'y': y_pred})
sub.query('y < 0')

# %%
for i in sub[sub['y'] < 0]['id']:
    sub['y'][i-1] = 0

# %%
sub['y'].describe()
# Out:
# count    34844.000000
# mean       255.487695
# std        720.185326
# min          0.000000
# 25%         95.087500
# 50%        147.230000
# 75%        219.152500
# max      54295.040000
# Name: y, dtype: float64

# %%
sub.to_csv('sub_lgbm_4.csv', index=False)

# %% [markdown]
# ## 超高額物件を抑えたほうがいいかもしれない

# %%
pd.DataFrame(y_high_pred).describe()
# Out:
#                   0
# count    223.000000
# mean    4201.273412
# std     5921.200854
# min      563.647235
# 25%     1443.199078
# 50%     2397.055699
# 75%     4531.237126
# max    52713.632942

# %%
 train.query('MunicipalityCode < 13150 and Area > 700')['y'].describe()
# Out:
# count     2938.000000
# mean      1288.696392
# std       2738.872598
# min          7.000000
# 25%        292.500000
# 50%        520.000000
# 75%       1200.000000
# max      61000.000000
# Name: y, dtype: float64

# %%
 # もっと高額の方は幅を持たせるべき！！！
train.query('MunicipalityCode < 13150 and Area > 2~300')['y'].describe() #でいい!!
# Out:
# Traceback (most recent call last):
#
#   File "/Users/endotakeru/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-48-dad3a9e48abb>", line 2, in <module>
#     train.query('MunicipalityCode < 13150 and Area > 2~300')['y'].describe() #でいい!!
#
#   File "/Users/endotakeru/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 3231, in query
#     res = self.eval(expr, **kwargs)
#
#   File "/Users/endotakeru/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 3346, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "/Users/endotakeru/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/eval.py", line 332, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "/Users/endotakeru/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py", line 764, in __init__
#     self.terms = self.parse()
#
#   File "/Users/endotakeru/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py", line 781, in parse
#     return self._visitor.visit(self.expr)
#
#   File "/Users/endotakeru/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py", line 371, in visit
#     raise e
#
#   File "/Users/endotakeru/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py", line 367, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#
#   File "/Users/endotakeru/opt/anaconda3/lib/python3.7/ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#
#   File "<unknown>", line 1
#     MunicipalityCode <13150 and Area >2 ~300
#                                         ^
# SyntaxError: Python keyword not valid identifier in numexpr query
